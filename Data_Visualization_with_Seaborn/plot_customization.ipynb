# %% [markdown]
# # PLOT CUSTOMIZATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.relplot(x='total_bill',
            y='tip',
            data=tips,
            kind='scatter',
            hue='smoker',
            size='size')

# set title and labels
g.fig.suptitle("Total Bills vs Tips")
g.set(xlabel='Total Bills',
      ylabel='Tips')



plt.show()

# %%
g = sns.relplot(x="tip",
            y='total_bill',
            data = tips,
            kind='line',
            hue= 'time',
            style='time'
            )
#set title and label
g.fig.suptitle("TOTAL BILLS VS TIPS")
g.set(xlabel='Tips',
      ylabel='Total Bills')
plt.show()

# %%
pop = pd.read_csv(r"c:/users/danhaya/arewads/world-population-dynamics/data/processed_data/processed_data.csv")

# %%
pop['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
africa20 = pop[pop['Continent']=='Africa']['2020 Population'].sum()
euro20 = pop[pop['Continent']== 'Europe']['2020 Population'].sum()
north20= pop[pop['Continent']=='North America']['2020 Population'].sum()
asia20 = pop[pop['Continent']=='Asia']['2020 Population'].sum()p
oceania20 = pop[pop['Continent']== 'Oceania']['2020 Population'].sum()
south20 = pop[pop['Continent']=='South America']['2020 Population'].sum()

# %%
continent = pd.DataFrame({
    "countries" : ["Africa", "Europe", "North America", "Asia", "Oceania", "South America"],
    "Population": [africa20, euro20, north20, asia20, oceania20, south20]
})

# %%
print(continent)
# Out:
#        countries  Population
# 0         Africa  1360671810
# 1         Europe   745792196
# 2  North America   594236593
# 3           Asia  4663086535
# 4        Oceania    43933426
# 5  South America   431530043

# %%
import matplotlib.pyplot as plt
import seaborn as sns

continent_color ={
    "Africa": "red",
    "Europe": "green",
    "North America": "blue",
    "Asia": "black",
    "South America": "orange",
    "Oceania": "purple"
}

#plot 

g = sns.catplot(x='countries',
            y='Population',
            data = continent,
            kind = 'bar',
            hue= 'countries',
            hue_order= continent_color)

#set label
g.fig.suptitle("Continent with their population")
g.set(xlabel='Countinent',
      ylabel= '2020 Population')

plt.xticks(rotation=45)

plt.show()

# %%
stock = pd.read_csv(r"c:/users/danhaya/arewads/arewads-fellowship/stock_market.csv")
print(stock.head())
# Out:
#    Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 0           0  02-02-2024              2.079               NaN
# 1           1  01-02-2024              2.050          161340.0
# 2           2  31-01-2024              2.100          142860.0
# 3           3  30-01-2024              2.077          139750.0
# 4           4  29-01-2024              2.490            3590.0
#
#    Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol. Bitcoin_Price  \
# 0            72.28             NaN        3.8215          NaN     43,194.70
# 1            73.82        577940.0        3.8535          NaN     43,081.40
# 2            75.85        344490.0        3.9060          NaN     42,580.50
# 3            77.82        347240.0        3.9110          NaN     42,946.20
# 4            76.78        331930.0        3.8790          NaN     43,299.80
#
#    Bitcoin_Vol.  ... Berkshire_Price  Berkshire_Vol. Netflix_Price  \
# ...

# %%
print(stock.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'Natural_Gas_Price', 'Natural_Gas_Vol.',
#        'Crude_oil_Price', 'Crude_oil_Vol.', 'Copper_Price', 'Copper_Vol.',
#        'Bitcoin_Price', 'Bitcoin_Vol.', 'Platinum_Price', 'Platinum_Vol.',
#        'Ethereum_Price', 'Ethereum_Vol.', 'S&P_500_Price', 'Nasdaq_100_Price',
#        'Nasdaq_100_Vol.', 'Apple_Price', 'Apple_Vol.', 'Tesla_Price',
#        'Tesla_Vol.', 'Microsoft_Price', 'Microsoft_Vol.', 'Silver_Price',
#        'Silver_Vol.', 'Google_Price', 'Google_Vol.', 'Nvidia_Price',
#        'Nvidia_Vol.', 'Berkshire_Price', 'Berkshire_Vol.', 'Netflix_Price',
#        'Netflix_Vol.', 'Amazon_Price', 'Amazon_Vol.', 'Meta_Price',
#        'Meta_Vol.', 'Gold_Price', 'Gold_Vol.'],
#       dtype='object')

# %%
stock_jan24 = stock['31-01-2024' : '02-01-2024']

# %%
plt.figure(figsize=(15,8))

g= sns.catplot(x=stock_jan24.index,
            y='Bitcoin_Price',
            data = stock_jan24,
            kind='point')

g.fig.suptitle("Bitcoin")
g.set(xlabel='Dates',
      ylabel= "Bitcoin Price")
plt.xticks(rotation=90)

plt.show()

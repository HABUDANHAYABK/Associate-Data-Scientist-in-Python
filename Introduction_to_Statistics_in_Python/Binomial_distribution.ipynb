# %% [markdown]
# # BINOMIAL DISTRIBUTIONS

# %%
import pandas as pd
import numpy as np
from scipy.stats import binom

#let me simulate single flip of coin

binom.rvs(1, 0.5, size=1)
# Out:
# array([1])

# %%
# flip of coin 8-times

binom.rvs(1, 0.5, size=8)
# Out:
# array([0, 0, 0, 0, 1, 0, 1, 0])

# %%
#flip 3coins, 10-times

binom.rvs(3, 0.5, 10)
# Out:
# 11

# %%
# What is the probability of 7 heads?
#P(heads=7)

from scipy.stats import binom
binom.pmf(7, 10, 0.5)
# Out:
# np.float64(0.11718749999999996)

# %%
#What is probabilty of 7 or fewer heads?

from scipy.stats import binom

print(f"The probabilty of have 7 or fewer heads is {(1 - binom.cdf(7, 10, 0.5)):.2f}")
# Out:
# The probabilty of have 7 or fewer heads is 0.05

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

n = 10
p = 0.5
size = 1000

#Generating binomial distribution samples
samples = np.random.binomial(n, p, size)

#plot histogram
plt.hist(samples, bins= np.arange(n+2)-0.5, density=True, alpha=0.7, color='blue', edgecolor='black')

# Overlay theoretical probability mass fuction
x = np.arange(0, n+1)
pmf = stats.binom.pmf(x, n, p)
plt.plot(x, pmf, 'ro-', label ='Theoretical PMF')

plt.xlabel("Number of heads")
plt.ylabel("Binomial Distribution")
plt.legend()

plt.show()

# %%
# Real world example
""" 
    A factory produces electronic chips, and 2% of them are defective. 
    if a batch of 50 chips is tested, what is the probability distribution of the number of defective chips?   
    """

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

n = 50 
p = 0.02
size = 1000
# size is the number of simulated batches

samples = np.random.binomial(n, p, size)

#plot
plt.hist(samples, bins= np.arange(n+2)-0.5, density=True, alpha=0.7, color='red', edgecolor='black')

#Overlay theoretical probability mass function
x = np.arange(0, n+1)
pmf = stats.binom.pmf(x, n, p)
plt.plot(x, pmf, 'ro-', label="Theoretical PMF")

plt.xlabel("Number defective chips")
plt.ylabel("Probablity")
plt.title("Binomial Distribution: Quality Control in a Factory")
plt.legend()

#display
plt.show()
